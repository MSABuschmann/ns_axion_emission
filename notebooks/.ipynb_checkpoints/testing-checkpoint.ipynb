# %%
import sys
import numpy as np
import h5py
import matplotlib
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d 

matplotlib.rcParams['text.usetex']    = True
matplotlib.rcParams['font.family']    = 'serif'
matplotlib.rcParams['font.size']      = '16'
matplotlib.rcParams['figure.figsize'] = 6.4, 4.8

# %%
APR = h5py.File('../output/APR_Cat_1.4.hdf5','r')
print(APR.keys())
# Out:
# <KeysViewHDF5 ['1s0n_N100', '1s0n_N1000', '1s0n_N10000', '1s0n_N262145', '1s0n_gsl', '1s0p_gsl', 'E', 'T_interp', 'Tcn_interp', 'params', 'r_interp', 'raw_T', 'raw_Tcn', 'raw_Tcp', 'raw_dvdr', 'raw_dvol', 'raw_ephi', 'raw_rT', 'raw_rTc', 'raw_state', 'thermal']>

# %%
params = APR['params'][:]
E = APR['E'][:]
spec_1s0n_N100 = APR['1s0n_N100'][:]
spec_1s0n_N1000 = APR['1s0n_N1000'][:]
spec_1s0n_N10000 = APR['1s0n_N10000'][:]
spec_1s0n_N262145 = APR['1s0n_N262145'][:]
spec_1s0n_gsl = APR['1s0n_gsl'][:]
spec_1s0p_gsl = APR['1s0p_gsl'][:]
thermal = APR['thermal'][:]

raw_rT = APR['raw_rT'][:]
raw_T = APR['raw_T'][:]
raw_ephi = APR['raw_ephi'][:]
raw_dvol = APR['raw_dvol'][:]
raw_dvdr = APR['raw_dvdr'][:]

raw_rTc = APR['raw_rTc'][:]
raw_Tcn = APR['raw_Tcn'][:]
raw_Tcp = APR['raw_Tcp'][:]
raw_state = APR['raw_state'][:]

r_interp = APR['r_interp'][:]
Tcn_interp = APR['Tcn_interp'][:]
T_interp = APR['T_interp'][:]

# %%
fig, ax = plt.subplots(figsize=(25,10), nrows=2, ncols=2)

ax[0,0].plot(raw_rTc, raw_Tcn, marker='.', label='n', color='black')
#ax[0,0].plot(r_interp, Tcn_interp, marker='', color='orange')
ax[0,0].plot(raw_rTc, raw_Tcp, marker='.', label='p', color='blue')
ax[0,0].legend()

ax[1,0].plot(raw_rT, raw_T, marker='.', color='black')
#ax[1,0].plot(r_interp, T_interp, marker='', color='orange')

ax[0,1].plot(raw_rT, raw_ephi, marker='.', color='black')

ax[1,1].plot(raw_rT, raw_dvdr, marker='.', color='black')

for i in [0,1]:
    for j in [0,1]:
        ax[i,j].set_xlim(0, np.max(raw_rT)*1.1)
        ax[i,j].set_xlabel(r'r [m]')
        ax[i,j].axvline(params[0], color='red')
        ax[i,j].axvline(params[1], color='red')

ax[0,0].set_ylim(0,)
ax[1,1].set_ylim(0,)
ax[0,0].set_ylabel(r'$T_c$ [K]')
ax[1,0].set_ylabel(r'$T$ [K]')
ax[0,1].set_ylabel(r'$e^{\phi}$')
ax[1,1].set_ylabel(r'$dV/dr$')
# Out:
# Text(0, 0.5, '$dV/dr$')

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(E, spec_1s0n_N100, marker='.', label=r'1s0(n), $N_r=100$', color='orange')
ax.plot(E, spec_1s0n_N1000, marker='.', label='1s0(n), $N_r=1000$', color='red')
ax.plot(E, spec_1s0n_N10000, marker='.', label='1s0(n), $N_r=10000$', color='blue')
ax.plot(E, spec_1s0n_N262145, marker='', label='1s0(n), $N_r=262145$', color='magenta')

ax.plot(E, spec_1s0n_gsl, marker='', label='1s0(n), GSL Romberg, n=19', color='black', linestyle='--')
plt.legend()
plt.ylim(0, 0.1)
plt.xlim(np.min(E), 50)
plt.xlabel(r'$E$ [keV]')
plt.ylabel(r'$\frac{1}{N_{a,\mathrm{PBF}}}\frac{d\epsilon}{dE}$')

#plt.yscale('log')
#plt.ylim(1e-18,)
# Out:
# Text(0, 0.5, '$\\frac{1}{N_{a,\\mathrm{PBF}}}\\frac{d\\epsilon}{dE}$')

# %%
fig, ax = plt.subplots(figsize=(12,5))
plt.axhline(0, color='gray')
ax.plot(E, spec_1s0n_gsl - spec_1s0n_N262145, marker='', label='difference', color='black')
#plt.ylim(0,6e-5)
plt.xlim(np.min(E), 50)
plt.xlabel(r'$E$ [keV]')
plt.ylabel(r'$\frac{1}{N_{a,\mathrm{PBF}}}\frac{d\epsilon}{dE}$')
# Out:
# Text(0, 0.5, '$\\frac{1}{N_{a,\\mathrm{PBF}}}\\frac{d\\epsilon}{dE}$')

# %%
K2keV = 8.61833e-8

def dFdE(E, T):
    z = E/T
    return 315./(124*np.pi**6)/T*z**3*(z**2 + 4*np.pi**2)/(np.exp(z)-1)

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(E, spec_1s0n_gsl, marker='', label='1s0(n)', color='black', linestyle='--')
ax.plot(E, spec_1s0p_gsl, marker='', label='1s0(p)', color='black', linestyle=':')
ax.plot(E, thermal, marker='', label='thermal (volume weighted)', color='blue', linestyle='-')   
plt.plot(E, dFdE(E, params[2] * K2keV/1.31), label='thermal (old paper)', color='blue', linestyle=':')
plt.plot(E, dFdE(E, params[2] * K2keV), label='thermal (old paper)', color='blue', linestyle=':')

plt.legend()
plt.ylim(0,0.06)
plt.xlim(np.min(E), 60)
plt.xlabel(r'$E$ [keV]')
plt.ylabel(r'$\frac{1}{N_{a,\mathrm{PBF}}}\frac{d\epsilon}{dE}$')

#plt.yscale('log')
#plt.ylim(1e-18,)
# Out:
# /tmp/ipykernel_536484/4089000839.py:5: RuntimeWarning: invalid value encountered in divide
#   return 315./(124*np.pi**6)/T*z**3*(z**2 + 4*np.pi**2)/(np.exp(z)-1)
# Text(0, 0.5, '$\\frac{1}{N_{a,\\mathrm{PBF}}}\\frac{d\\epsilon}{dE}$')

# %%
np.sum(dFdE(E[1:], params[2] * K2keV/1.31)), np.sum(spec_1s0p_gsl)
# Out:
# (6.659999987076524, 6.666666666666657)

# %%
n = np.array([1.78268, 3.12285, 2.77691])
p = np.array([26.7282, 47.1823, 40.9827])

# %%
print(n/np.sum(n))
# Out:
# [0.23204607 0.40649195 0.36146198]

# %%
print(p/np.sum(p))
# Out:
# [0.23263518 0.41066225 0.35670257]

# %%
K2keV = 8.61833e-8

def dFdE(E, T):
    z = E/T
    #print(E,T,z)
    return 315./(125*np.pi**6)/T*z**3*(z**2 + 4*np.pi**2)/(np.exp(z)-1)
         
plt.plot(E[10:], dFdE(E[10:], 5.))
plt.legend()
plt.xlim(np.min(E), 50)
plt.xlabel(r'$E$ [keV]')
#plt.xscale('log')
#plt.yscale('log')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, '$E$ [keV]')

# %%
1e9 * 0.64 * 8.61833e-8
# Out:
# 55.157312
